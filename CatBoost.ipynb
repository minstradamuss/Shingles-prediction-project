# %%
import json
import pandas as pd
from tqdm.notebook import tqdm

data_file = 'dataset_shingles_maria_sample_5'
l = []

with open(data_file) as reader:
    for obj in tqdm(reader):
        try:
            line = json.loads(obj)
            l.append(line)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")
            continue  # Skip invalid lines


df_data = pd.DataFrame(l)
# Out:
# 0it [00:00, ?it/s]

# %%
df_tmp = df_data.iloc[:100]

# %%
df_tmp
# Out:
#        num  hard_target                                           shingles  \
# 0   150381        False  [396334907, 1060847325, 1063332450, 1330563559...
# 1   150383        False  [396334907, 1060847325, 1063332450, 1330563559...
# 2   150384        False  [227257338, 329292840, 463346217, 1029363358, ...
# 3   150385        False  [104601096, 422258184, 549984431, 560494154, 5...
# 4   150387        False  [2039583, 4137730, 5047731, 6762261, 6993977, ...
# ..     ...          ...                                                ...
# 95  150542        False  [3269003, 12741328, 14442492, 16473842, 230843...
# 96  150543        False  [12096343, 19752179, 20324125, 23799634, 25459...
# 97  150544        False  [409378754, 1014151031, 1437623850, 1850578463...
# 98  150553        False  [43447116, 55599410, 81608462, 122942364, 1364...
# 99  150554        False  [87343846, 100823462, 191356912, 194972896, 21...
#
#     soft_target
# 0         False
# 1         False
# 2          True
# 3          True
# 4          True
# ..          ...
# 95        False
# 96        False
# 97         True
# 98        False
# 99        False
#
# [100 rows x 4 columns]

# %%
from collections import defaultdict

shingle_counts = defaultdict(lambda: {"b": 0, "c": 0})
for _, row in df_data.iterrows():
    for shingle in row['shingles']:
        shingle_counts[shingle]["c"] += 1
        if row['hard_target'] or row['soft_target']:
            shingle_counts[shingle]["b"] += 1

selected_shingles = {
    shingle: counts
    for shingle, counts in shingle_counts.items()
    if counts["b"] > 1 or counts["c"] > 100
}

shingle_groups = {k: set() for k in range(10)}
for shingle, counts in selected_shingles.items():
    ratio = counts["b"] / counts["c"]
    for k in range(10):
        if 0.1 * k <= ratio < 0.1 * (k + 1):
            shingle_groups[k].add(shingle)
            break

# %%
final_table = []
for _, row in df_data.iterrows():
    shingles = set(row['shingles'])
    features = {
        f"feature_{k}": len(shingles.intersection(shingle_groups[k])) / len(shingles) if shingles else 0
        for k in range(10)
    }
    features.update({
        "num": row['num'],
        "soft_target": row['soft_target'],
        "hard_target": row['hard_target']
    })
    final_table.append(features)

# %%
final_table
# Out:
# [{'feature_0': 1.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150381,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 1.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150383,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150384,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.03571428571428571,
#   'feature_5': 0.03571428571428571,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150385,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0004837929366231253,
#   'feature_6': 0.0,
#   'feature_7': 0.0019351717464925011,
#   'feature_8': 0.006289308176100629,
#   'feature_9': 0.028059990324141266,
#   'num': 150387,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150393,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150396,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.3,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150397,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0009140767824497258,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150398,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.002028397565922921,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150402,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150403,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.009708737864077669,
#   'feature_3': 0.14563106796116504,
#   'feature_4': 0.27184466019417475,
#   'feature_5': 0.3786407766990291,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150406,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150407,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.04938271604938271,
#   'feature_1': 0.07407407407407407,
#   'feature_2': 0.0,
#   'feature_3': 0.012345679012345678,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150409,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150410,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.00025464731347084286,
#   'feature_4': 0.0,
#   'feature_5': 0.0005092946269416857,
#   'feature_6': 0.0007639419404125286,
#   'feature_7': 0.0012732365673542145,
#   'feature_8': 0.0030557677616501145,
#   'feature_9': 0.034886681945505475,
#   'num': 150411,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0002553626149131767,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0005107252298263534,
#   'feature_8': 0.0007660878447395301,
#   'feature_9': 0.0372829417773238,
#   'num': 150412,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.007692307692307693,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150413,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150414,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0021929824561403508,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.008771929824561403,
#   'num': 150415,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.64,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150416,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.00017627357659086903,
#   'feature_6': 0.00017627357659086903,
#   'feature_7': 0.0,
#   'feature_8': 0.0005288207297726071,
#   'feature_9': 0.04248193195839944,
#   'num': 150417,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.005154639175257732,
#   'feature_8': 0.0,
#   'feature_9': 0.05154639175257732,
#   'num': 150418,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.05555555555555555,
#   'feature_7': 0.0,
#   'feature_8': 0.05555555555555555,
#   'feature_9': 0.0,
#   'num': 150419,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.00017627357659086903,
#   'feature_6': 0.00017627357659086903,
#   'feature_7': 0.0,
#   'feature_8': 0.0005288207297726071,
#   'feature_9': 0.04248193195839944,
#   'num': 150420,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.07317073170731707,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150421,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.006024096385542169,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150422,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.04938271604938271,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 150423,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150424,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 150425,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.8695652173913043,
#   'num': 150433,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150434,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.08949416342412451,
#   'feature_1': 0.007782101167315175,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150436,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 1.0,
#   'num': 150437,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.023346303501945526,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150440,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.018433179723502304,
#   'num': 150441,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150442,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.010416666666666666,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150444,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150445,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150452,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.125,
#   'feature_1': 0.75,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150456,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.018518518518518517,
#   'feature_4': 0.0,
#   'feature_5': 0.2037037037037037,
#   'feature_6': 0.037037037037037035,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150457,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.08333333333333333,
#   'feature_4': 0.16666666666666666,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150458,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.2222222222222222,
#   'num': 150459,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.10606060606060606,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150461,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.022727272727272728,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150462,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.01079136690647482,
#   'feature_1': 0.0007194244604316547,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150463,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.002849002849002849,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150465,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150466,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.2727272727272727,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.2727272727272727,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150467,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.07042253521126761,
#   'feature_4': 0.3028169014084507,
#   'feature_5': 0.4859154929577465,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150468,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.010893246187363835,
#   'feature_3': 0.006535947712418301,
#   'feature_4': 0.002178649237472767,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150469,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0019011406844106464,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150472,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.004405286343612335,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150473,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.022388059701492536,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150476,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150479,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150480,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.014168530947054437,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0007457121551081282,
#   'feature_5': 0.0014914243102162564,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150481,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.010230179028132993,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150482,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.022332506203473945,
#   'feature_1': 0.10669975186104218,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0024813895781637717,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150483,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.01694915254237288,
#   'feature_2': 0.8389830508474576,
#   'feature_3': 0.03389830508474576,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150485,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0625,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150486,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150487,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.00298804780876494,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.00099601593625498,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150491,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150493,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150494,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.05063291139240506,
#   'num': 150495,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.004545454545454545,
#   'feature_7': 0.0,
#   'feature_8': 0.004545454545454545,
#   'feature_9': 0.08636363636363636,
#   'num': 150496,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.03129890453834116,
#   'num': 150497,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.004347826086956522,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.05652173913043478,
#   'num': 150498,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150499,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 150504,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 150505,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0006157635467980296,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0006157635467980296,
#   'feature_6': 0.0,
#   'feature_7': 0.003078817733990148,
#   'feature_8': 0.0049261083743842365,
#   'feature_9': 0.013546798029556651,
#   'num': 150506,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.00234192037470726,
#   'feature_1': 0.00234192037470726,
#   'feature_2': 0.00234192037470726,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.00234192037470726,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150507,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.09090909090909091,
#   'feature_6': 0.0,
#   'feature_7': 0.3181818181818182,
#   'feature_8': 0.045454545454545456,
#   'feature_9': 0.4090909090909091,
#   'num': 150511,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150518,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150519,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150520,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150521,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150522,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.005263157894736842,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150523,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.006230529595015576,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150524,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0007468259895444362,
#   'feature_8': 0.0014936519790888724,
#   'feature_9': 0.0,
#   'num': 150527,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150528,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.003278688524590164,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150529,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0049261083743842365,
#   'feature_1': 0.0049261083743842365,
#   'feature_2': 0.0049261083743842365,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150530,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150531,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.8536585365853658,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150532,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.021505376344086023,
#   'feature_6': 0.010752688172043012,
#   'feature_7': 0.0,
#   'feature_8': 0.010752688172043012,
#   'feature_9': 0.010752688172043012,
#   'num': 150533,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150534,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.4375,
#   'feature_8': 0.0625,
#   'feature_9': 0.5,
#   'num': 150535,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.005434782608695652,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.018115942028985508,
#   'num': 150537,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0011750881316098707,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0005875440658049354,
#   'feature_9': 0.0005875440658049354,
#   'num': 150538,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150539,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0026246719160104987,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150542,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150543,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.375,
#   'num': 150544,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150553,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150554,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0008040739748056821,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150555,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.8780487804878049,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150558,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150559,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.037037037037037035,
#   'feature_6': 0.012345679012345678,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 150560,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150562,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0013513513513513514,
#   'feature_1': 0.0013513513513513514,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150564,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.05263157894736842,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150567,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.8888888888888888,
#   'feature_4': 0.1111111111111111,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150568,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0034602076124567475,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150572,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 1.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150573,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.000731528895391368,
#   'feature_5': 0.000731528895391368,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.000731528895391368,
#   'feature_9': 0.000731528895391368,
#   'num': 150574,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.008836524300441826,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0014727540500736377,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150577,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150579,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.015384615384615385,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.6923076923076923,
#   'num': 150580,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150581,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.23076923076923078,
#   'num': 150582,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0005374899220639613,
#   'feature_2': 0.0002687449610319806,
#   'feature_3': 0.0002687449610319806,
#   'feature_4': 0.0,
#   'feature_5': 0.0005374899220639613,
#   'feature_6': 0.0002687449610319806,
#   'feature_7': 0.0,
#   'feature_8': 0.0005374899220639613,
#   'feature_9': 0.0008062348830959419,
#   'num': 150583,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.64,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150584,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.5882352941176471,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150585,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.3333333333333333,
#   'num': 150586,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 1.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150587,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.3333333333333333,
#   'num': 150588,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.3333333333333333,
#   'num': 150589,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.3333333333333333,
#   'num': 150590,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0008216926869350862,
#   'num': 150592,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150595,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150596,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150598,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0019455252918287938,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150600,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.011363636363636364,
#   'feature_6': 0.3068181818181818,
#   'feature_7': 0.011363636363636364,
#   'feature_8': 0.45454545454545453,
#   'feature_9': 0.0,
#   'num': 150601,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0027247956403269754,
#   'feature_3': 0.0,
#   'feature_4': 0.0027247956403269754,
#   'feature_5': 0.0027247956403269754,
#   'feature_6': 0.0027247956403269754,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.01907356948228883,
#   'num': 150602,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150606,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0018083182640144665,
#   'feature_2': 0.003616636528028933,
#   'feature_3': 0.003616636528028933,
#   'feature_4': 0.0108499095840868,
#   'feature_5': 0.0,
#   'feature_6': 0.0054249547920434,
#   'feature_7': 0.0,
#   'feature_8': 0.007233273056057866,
#   'feature_9': 0.0018083182640144665,
#   'num': 150610,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.00980392156862745,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150612,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.041025641025641026,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.010256410256410256,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150614,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150615,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0025284450063211127,
#   'feature_1': 0.0,
#   'feature_2': 0.0012642225031605564,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150622,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.02040816326530612,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150624,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.08108108108108109,
#   'feature_1': 0.0,
#   'feature_2': 0.05405405405405406,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.02702702702702703,
#   'feature_9': 0.0,
#   'num': 150625,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0010111223458038423,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0010111223458038423,
#   'num': 150628,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150629,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150630,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.012012012012012012,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150631,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.11013215859030837,
#   'feature_1': 0.0022026431718061676,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150632,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150633,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150635,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150640,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150641,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150644,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150646,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0029154518950437317,
#   'feature_1': 0.0,
#   'feature_2': 0.0029154518950437317,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150647,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0025906735751295338,
#   'feature_9': 0.7227979274611399,
#   'num': 150649,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150650,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.017391304347826087,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150653,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0007668711656441718,
#   'feature_1': 0.0,
#   'feature_2': 0.0007668711656441718,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0007668711656441718,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150655,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.003865267807840972,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150658,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.01455604075691412,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.001455604075691412,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150659,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150661,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150663,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0009191176470588235,
#   'feature_3': 0.001838235294117647,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0009191176470588235,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150664,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.010752688172043012,
#   'feature_1': 0.012903225806451613,
#   'feature_2': 0.0017204301075268817,
#   'feature_3': 0.0017204301075268817,
#   'feature_4': 0.0,
#   'feature_5': 0.00043010752688172043,
#   'feature_6': 0.0,
#   'feature_7': 0.00043010752688172043,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150667,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150670,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.00031289111389236547,
#   'feature_2': 0.0006257822277847309,
#   'feature_3': 0.00031289111389236547,
#   'feature_4': 0.0009386733416770963,
#   'feature_5': 0.01095118898623279,
#   'feature_6': 0.011576971214017523,
#   'feature_7': 0.004380475594493116,
#   'feature_8': 0.0031289111389236545,
#   'feature_9': 0.0031289111389236545,
#   'num': 150671,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.00819672131147541,
#   'feature_2': 0.0,
#   'feature_3': 0.00819672131147541,
#   'feature_4': 0.00819672131147541,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150672,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150673,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 150674,
# ...
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152147,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.21428571428571427,
#   'feature_4': 0.21428571428571427,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152148,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.02127659574468085,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152149,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152150,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152151,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152153,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.001597444089456869,
#   'feature_1': 0.007987220447284345,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152156,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152157,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152158,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 1.0,
#   'num': 152161,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152163,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152168,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.006622516556291391,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152169,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.07692307692307693,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152170,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.5,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152173,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.003952569169960474,
#   'feature_2': 0.007905138339920948,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152177,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152178,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.001968503937007874,
#   'feature_9': 0.003937007874015748,
#   'num': 152179,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.00130718954248366,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152180,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152181,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.8333333333333334,
#   'num': 152182,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.015873015873015872,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.015873015873015872,
#   'num': 152187,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.004415011037527594,
#   'feature_1': 0.002207505518763797,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152189,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.029411764705882353,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.029411764705882353,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152190,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0043859649122807015,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.039473684210526314,
#   'num': 152192,
#   'soft_target': True,
#   'hard_target': True},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.42857142857142855,
#   'num': 152194,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.00847457627118644,
#   'feature_1': 0.0,
#   'feature_2': 0.00847457627118644,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.00423728813559322,
#   'feature_9': 0.0,
#   'num': 152197,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0625,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152198,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152200,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.004098360655737705,
#   'feature_1': 0.004098360655737705,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152204,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152205,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.007462686567164179,
#   'feature_5': 0.014925373134328358,
#   'feature_6': 0.05970149253731343,
#   'feature_7': 0.029850746268656716,
#   'feature_8': 0.7388059701492538,
#   'feature_9': 0.0,
#   'num': 152210,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.003484320557491289,
#   'feature_1': 0.2665505226480836,
#   'feature_2': 0.09407665505226481,
#   'feature_3': 0.1480836236933798,
#   'feature_4': 0.1602787456445993,
#   'feature_5': 0.0017421602787456446,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152211,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.027777777777777776,
#   'feature_2': 0.009259259259259259,
#   'feature_3': 0.4722222222222222,
#   'feature_4': 0.3055555555555556,
#   'feature_5': 0.14814814814814814,
#   'feature_6': 0.027777777777777776,
#   'feature_7': 0.0,
#   'feature_8': 0.009259259259259259,
#   'feature_9': 0.0,
#   'num': 152213,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152215,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.13846153846153847,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152218,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152219,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152220,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152221,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152222,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152223,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.011627906976744186,
#   'feature_6': 0.2441860465116279,
#   'feature_7': 0.011627906976744186,
#   'feature_8': 0.5581395348837209,
#   'feature_9': 0.0,
#   'num': 152224,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.04938271604938271,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 152225,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.04938271604938271,
#   'feature_7': 0.012345679012345678,
#   'feature_8': 0.7283950617283951,
#   'feature_9': 0.024691358024691357,
#   'num': 152226,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.00035373187124159886,
#   'feature_6': 0.0,
#   'feature_7': 0.0010611956137247967,
#   'feature_8': 0.0017686593562079944,
#   'feature_9': 0.04067916519278387,
#   'num': 152227,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.14285714285714285,
#   'feature_8': 0.14285714285714285,
#   'feature_9': 0.42857142857142855,
#   'num': 152228,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0006920415224913495,
#   'feature_6': 0.0020761245674740486,
#   'feature_7': 0.00657439446366782,
#   'feature_8': 0.5795847750865052,
#   'feature_9': 0.4096885813148789,
#   'num': 152233,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.75,
#   'feature_8': 0.25,
#   'feature_9': 0.0,
#   'num': 152234,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.00025464731347084286,
#   'feature_4': 0.0,
#   'feature_5': 0.0005092946269416857,
#   'feature_6': 0.0007639419404125286,
#   'feature_7': 0.0012732365673542145,
#   'feature_8': 0.0030557677616501145,
#   'feature_9': 0.034886681945505475,
#   'num': 152235,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.0004580852038479157,
#   'feature_1': 0.0,
#   'feature_2': 0.0009161704076958314,
#   'feature_3': 0.0009161704076958314,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0004580852038479157,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0004580852038479157,
#   'num': 152236,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 1.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152241,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0040650406504065045,
#   'feature_1': 0.0040650406504065045,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152242,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.0,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.02631578947368421,
#   'feature_4': 0.02631578947368421,
#   'feature_5': 0.5657894736842105,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152243,
#   'soft_target': True,
#   'hard_target': False},
#  {'feature_0': 0.008620689655172414,
#   'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152244,
#   'soft_target': False,
#   'hard_target': False},
#  {'feature_0': 0.010614772224679346,
#   'feature_1': 0.0004422821760283061,
#   'feature_2': 0.0004422821760283061,
#   'feature_3': 0.0013268465280849183,
#   'feature_4': 0.0,
#   'feature_5': 0.0,
#   'feature_6': 0.0,
#   'feature_7': 0.0,
#   'feature_8': 0.0,
#   'feature_9': 0.0,
#   'num': 152245,
#   'soft_target': False,
#   'hard_target': False},
#  ...]

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 23.2 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
final_df = final_table

# %%
final_df = pd.DataFrame(final_df)

# %%
final_df
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0       1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1       1.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2       0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 3       0.000000   0.000000   0.000000   0.000000   0.035714   0.035714
# 4       0.000000   0.000000   0.000000   0.000000   0.000000   0.000484
# ...          ...        ...        ...        ...        ...        ...
# 19995   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 19996   0.015453   0.000000   0.000000   0.000000   0.000000   0.000000
# 19997   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 19998   0.007236   0.100579   0.029667   0.051375   0.054269   0.011577
# 19999   0.003209   0.002139   0.004278   0.000000   0.000000   0.000000
#
#        feature_6  feature_7  feature_8  feature_9     num  soft_target  \
# 0            0.0   0.000000   0.000000    0.00000  150381        False
# 1            0.0   0.000000   0.000000    0.00000  150383        False
# 2            0.0   0.000000   0.000000    0.00000  150384         True
# 3            0.0   0.000000   0.000000    0.00000  150385         True
# 4            0.0   0.001935   0.006289    0.02806  150387         True
# ...          ...        ...        ...        ...     ...          ...
# 19995        0.0   0.000000   0.000000    0.00000  188241        False
# 19996        0.0   0.000000   0.000000    0.00000  188243        False
# 19997        0.0   0.000000   0.000000    0.00000  188247        False
# 19998        0.0   0.000000   0.000724    0.00000  188250        False
# 19999        0.0   0.000000   0.000000    0.00000  188251        False
#
#        hard_target
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ...            ...
# 19995        False
# 19996        False
# 19997        False
# 19998        False
# 19999        False
#
# [20000 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
import numpy as np

final_df['hard_target_correct'] = final_df['hard_target']
final_df['soft_target_correct'] = final_df['soft_target']

X = final_df[['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4',
              'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9']]
y_hard = final_df['hard_target_correct'].astype(int)
y_soft = final_df['soft_target_correct'].astype(int)

X_train_hard, X_test_hard, y_train_hard, y_test_hard = train_test_split(X, y_hard, test_size=0.3, random_state=42)
X_train_soft, X_test_soft, y_train_soft, y_test_soft = train_test_split(X, y_soft, test_size=0.3, random_state=42)

def train_and_evaluate_model(X_train, X_test, y_train, y_test, model_name):
    results = {}

    cat_model = CatBoostClassifier(verbose=0)
    cat_model.fit(X_train, y_train)
    y_pred_cat = cat_model.predict(X_test)
    y_prob_cat = cat_model.predict_proba(X_test)[:, 1]

    results['CatBoost'] = {
        'Accuracy': accuracy_score(y_test, y_pred_cat),
        'ROC-AUC': roc_auc_score(y_test, y_prob_cat),
        'Precision': precision_score(y_test, y_pred_cat),
        'Recall': recall_score(y_test, y_pred_cat),
    }

    xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
    xgb_model.fit(X_train, y_train)
    y_pred_xgb = xgb_model.predict(X_test)
    y_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]

    results['XGBoost'] = {
        'Accuracy': accuracy_score(y_test, y_pred_xgb),
        'ROC-AUC': roc_auc_score(y_test, y_prob_xgb),
        'Precision': precision_score(y_test, y_pred_xgb),
        'Recall': recall_score(y_test, y_pred_xgb),
    }

    print(f"\nMetrics for {model_name}:")
    for model, metrics in results.items():
        print(f"{model}:")
        for metric, value in metrics.items():
            print(f"  {metric}: {value:.4f}")

    return results

hard_results = train_and_evaluate_model(X_train_hard, X_test_hard, y_train_hard, y_test_hard, "Hard Target")

soft_results = train_and_evaluate_model(X_train_soft, X_test_soft, y_train_soft, y_test_soft, "Soft Target")
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [04:51:09] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Metrics for Hard Target:
# CatBoost:
#   Accuracy: 0.9620
#   ROC-AUC: 0.9179
#   Precision: 0.8030
#   Recall: 0.5524
# XGBoost:
#   Accuracy: 0.9623
#   ROC-AUC: 0.9222
#   Precision: 0.8022
#   Recall: 0.5601
#
# Metrics for Soft Target:
# CatBoost:
#   Accuracy: 0.9072
#   ROC-AUC: 0.9135
#   Precision: 0.9022
#   Recall: 0.7081
# XGBoost:
#   Accuracy: 0.9067
#   ROC-AUC: 0.9134
#   Precision: 0.9054
#   Recall: 0.7028
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [04:51:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
